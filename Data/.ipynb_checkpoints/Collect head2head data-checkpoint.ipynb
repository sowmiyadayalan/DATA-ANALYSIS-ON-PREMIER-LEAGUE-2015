# %%
import requests
import os
import json
import time
ind_article_list=[]
season_yr='2015'

competition_list=requests.get("http://api.football-data.org/v1/fixtures/150795?head2head=50").json()
#competition_list=requests.get("http://api.football-data.org/v1/competitions/398/teams").json()
#competition_list

# %%
competition_list
# Out:
# {'fixture': {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/64'},
#    'competition': {'href': 'http://api.football-data.org/v1/competitions/426'},
#    'homeTeam': {'href': 'http://api.football-data.org/v1/teams/61'},
#    'self': {'href': 'http://api.football-data.org/v1/fixtures/150795'}},
#   'awayTeamName': 'Liverpool FC',
#   'date': '2016-09-16T19:00:00Z',
#   'homeTeamName': 'Chelsea FC',
#   'matchday': 5,
#   'odds': {'awayWin': 3.25, 'draw': 3.5, 'homeWin': 2.15},
#   'result': {'goalsAwayTeam': 2, 'goalsHomeTeam': 1},
#   'status': 'FINISHED'},
#  'head2head': {'awayTeamWins': 16,
#   'count': 50,
#   'draws': 15,
#   'fixtures': [{'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/61'},
#      'competition': {'href': 'http://api.football-data.org/v1/competitions/426'},
#      'homeTeam': {'href': 'http://api.football-data.org/v1/teams/64'},
#      'self': {'href': 'http://api.football-data.org/v1/fixtures/150615'}},
# ...

# %%
head2head_list=requests.get("http://api.football-data.org/v1/teams/61/fixtures?head2head=3").json()

# %%
head2head_list
# Out:
# {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/61/fixtures'},
#   'team': {'href': 'http://api.football-data.org/v1/teams/61'}},
#  'count': 43,
#  'fixtures': [{'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/563'},
#     'competition': {'href': 'http://api.football-data.org/v1/competitions/426'},
#     'homeTeam': {'href': 'http://api.football-data.org/v1/teams/61'},
#     'self': {'href': 'http://api.football-data.org/v1/fixtures/150838'}},
#    'awayTeamName': 'West Ham United FC',
#    'date': '2016-08-15T19:00:00Z',
#    'homeTeamName': 'Chelsea FC',
#    'matchday': 1,
#    'odds': {'awayWin': 5.5, 'draw': 3.75, 'homeWin': 1.61},
#    'result': {'goalsAwayTeam': 1, 'goalsHomeTeam': 2},
#    'status': 'FINISHED'},
#   {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/61'},
#     'competition': {'href': 'http://api.football-data.org/v1/competitions/426'},
# ...
